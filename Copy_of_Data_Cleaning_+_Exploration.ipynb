# %% [markdown]
# ## 1. Importing Libraries/Tools

# %%
# !pip install num2words
# !pip install rake_nltk
# !pip install yake

from google.colab import drive
drive.mount('/content/drive')

import datetime
import dateutil
import itertools
import gensim
import gensim.downloader as api
import nltk
import numpy as np
import operator
import pandas as pd
import rake_nltk
import re
import sklearn
import spacy
import string
import yake

from datetime import datetime
from dateutil.relativedelta import relativedelta
from gensim import corpora
from gensim.models import Word2Vec, KeyedVectors
from gensim.summarization import keywords
from gensim.summarization.summarizer import summarize
from nltk.stem import PorterStemmer
from nltk.stem import WordNetLemmatizer
from nltk.tokenize import word_tokenize
from num2words import num2words
from rake_nltk import Rake
from sklearn.cluster import KMeans
from sklearn.neighbors import KDTree
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from spacy import displacy
from spacy.tokenizer import Tokenizer

nltk.download('omw-1.4')
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('words')
nltk.download('wordnet')
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting num2words
#   Downloading num2words-0.5.12-py3-none-any.whl (125 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 125.2/125.2 KB 9.4 MB/s eta 0:00:00
# Collecting docopt>=0.6.2
#   Downloading docopt-0.6.2.tar.gz (25 kB)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: docopt
#   Building wheel for docopt (setup.py) ... done
#   Created wheel for docopt: filename=docopt-0.6.2-py2.py3-none-any.whl size=13723 sha256=ba2f5e41f117896fd34ffc2fbdc867c39db9f06d3d7578c86c0b6bc40c5a3e28
#   Stored in directory: /root/.cache/pip/wheels/56/ea/58/ead137b087d9e326852a851351d1debf4ada529b6ac0ec4e8c
# Successfully built docopt
# Installing collected packages: docopt, num2words
# Successfully installed docopt-0.6.2 num2words-0.5.12
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting rake_nltk
#   Downloading rake_nltk-1.0.6-py3-none-any.whl (9.1 kB)
# Requirement already satisfied: nltk<4.0.0,>=3.6.2 in /usr/local/lib/python3.8/dist-packages (from rake_nltk) (3.7)
# Requirement already satisfied: click in /usr/local/lib/python3.8/dist-packages (from nltk<4.0.0,>=3.6.2->rake_nltk) (7.1.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.8/dist-packages (from nltk<4.0.0,>=3.6.2->rake_nltk) (2022.6.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.8/dist-packages (from nltk<4.0.0,>=3.6.2->rake_nltk) (4.64.1)
# Requirement already satisfied: joblib in /usr/local/lib/python3.8/dist-packages (from nltk<4.0.0,>=3.6.2->rake_nltk) (1.2.0)
# Installing collected packages: rake_nltk
# Successfully installed rake_nltk-1.0.6
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting yake
#   Downloading yake-0.4.8-py2.py3-none-any.whl (60 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.2/60.2 KB 5.7 MB/s eta 0:00:00
# Requirement already satisfied: click>=6.0 in /usr/local/lib/python3.8/dist-packages (from yake) (7.1.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.8/dist-packages (from yake) (3.0)
# Collecting segtok
#   Downloading segtok-1.5.11-py3-none-any.whl (24 kB)
# Requirement already satisfied: tabulate in /usr/local/lib/python3.8/dist-packages (from yake) (0.8.10)
# Requirement already satisfied: numpy in /usr/local/lib/python3.8/dist-packages (from yake) (1.22.4)
# Collecting jellyfish
#   Downloading jellyfish-0.9.0.tar.gz (132 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.6/132.6 KB 16.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: regex in /usr/local/lib/python3.8/dist-packages (from segtok->yake) (2022.6.2)
# Building wheels for collected packages: jellyfish
#   Building wheel for jellyfish (setup.py) ... done
#   Created wheel for jellyfish: filename=jellyfish-0.9.0-cp38-cp38-linux_x86_64.whl size=77913 sha256=79007128dae3ab9b7709f62c58e4ca4d4ac5ccf8445d31b924bb06d698780984
#   Stored in directory: /root/.cache/pip/wheels/f1/c7/3c/4c83132de76359e3a429fd09c08995945ca96c5290a41651d3
# Successfully built jellyfish
# Installing collected packages: segtok, jellyfish, yake
# Successfully installed jellyfish-0.9.0 segtok-1.5.11 yake-0.4.8
# Mounted at /content/drive
# /usr/local/lib/python3.8/dist-packages/torch/cuda/__init__.py:497: UserWarning: Can't initialize NVML
#   warnings.warn("Can't initialize NVML")
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package words to /root/nltk_data...
# [nltk_data]   Unzipping corpora/words.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# True

# %% [markdown]
# ## 2. Load Relevant Data

# %%
df1 = pd.read_csv('/content/drive/MyDrive/BT4103/Resume.csv')
df1 = df1[['Category','Resume_str']]
df1.Resume_str = df1.Resume_str.apply(lambda x: " ".join(x.split()))

df2 = pd.read_csv('/content/drive/MyDrive/BT4103/Job Description.csv')
df2["job_post_lang"] = df2["job_post_lang"].apply(lambda x: x.lower())
df2 = df2[df2["job_post_lang"] == "en-gb"]
df2 = df2[['category','job_requirements']]
df2 = df2.dropna()

skills_api = pd.read_excel('/content/drive/MyDrive/BT4103/all_skills_emsi.xlsx')
skills_api['name'] = skills_api['name'].apply(lambda x: re.sub("\W?\(.*?\)","",x))
skills_api['name'] = skills_api['name'].apply(lambda x: x.strip().lower())
skills_api = set(skills_api['name'])

# %% [markdown]
# ## 3. Resume Data Exploration

# %%
df1.Category.value_counts()
# Out:
# INFORMATION-TECHNOLOGY    120
# BUSINESS-DEVELOPMENT      120
# FINANCE                   118
# ADVOCATE                  118
# ACCOUNTANT                118
# ENGINEERING               118
# CHEF                      118
# AVIATION                  117
# FITNESS                   117
# SALES                     116
# BANKING                   115
# HEALTHCARE                115
# CONSULTANT                115
# CONSTRUCTION              112
# PUBLIC-RELATIONS          111
# HR                        110
# DESIGNER                  107
# ARTS                      103
# TEACHER                   102
# APPAREL                    97
# DIGITAL-MEDIA              96
# AGRICULTURE                63
# AUTOMOBILE                 36
# BPO                        22
# Name: Category, dtype: int64

# %%
df1[df1.Category == "INFORMATION-TECHNOLOGY"]
# Out:
#                    Category                                         Resume_str
# 217  INFORMATION-TECHNOLOGY  INFORMATION TECHNOLOGY Summary Dedicated Infor...
# 218  INFORMATION-TECHNOLOGY  INFORMATION TECHNOLOGY SPECIALIST GS11 Experie...
# 219  INFORMATION-TECHNOLOGY  INFORMATION TECHNOLOGY SUPERVISOR Summary Seek...
# 220  INFORMATION-TECHNOLOGY  INFORMATION TECHNOLOGY INSTRUCTOR Summary Seve...
# 221  INFORMATION-TECHNOLOGY  INFORMATION TECHNOLOGY MANAGER/ANALYST Profess...
# ..                      ...                                                ...
# 332  INFORMATION-TECHNOLOGY  CORPORATE PROJECT MANAGER Career Overview Seas...
# 333  INFORMATION-TECHNOLOGY  IT TECHNOLOGY SPECIALIST Professional Summary ...
# 334  INFORMATION-TECHNOLOGY  IT MANAGER Highlights Customer and Client Rela...
# 335  INFORMATION-TECHNOLOGY  SUBJECT MATTER EXPERT (INFORMATION TECHNOLOGY ...
# 336  INFORMATION-TECHNOLOGY  TRAINING MANAGER Executive Summary Qualified T...
#
# [120 rows x 2 columns]

# %%
# Test cases
test1 = 'Wong Yung Jer          : (+65) 88870515   : wongyungjer29@gmail.com   : Wong Yung Jer   : Yung-Jer EDUCATION  National University of Singapore (NUS) Aug 2020 – Present • Bachelor of Science in Business Analytics (School of Computing), Year 3  • CAP: 4.70/5.00  • Recipient of ASEAN Undergraduate Scholarship Award  • Dean’s List Student  EXPERIENCE  Undergraduate Student Teaching Assistant, NUS School of Computing  Aug 2022 – Present  • Experienced teaching assistant with a passion for inspiring other students in Mathematics and Artificial Intelligence • Shaped and fostered a conducive classroom environment for free discussion • Conducting weekly tutorials for: • BT2103 Optimization Methods in Business Analytics • BT3017 Feature Engineering for Machine Learning Student Developer, Back-end Web Application Development  Aug 2021 – Present  • Executed the developing, testing, debugging and maintenance of a web system  • Established rest API, routings, input validation testing, documentation with CodeIgniter 3 framework  • Designed a system and helped eliminate up to 95% of manual work to handle form submissions  CO-CURRICULAR ACTIVITIES  Outreach Team Member, NUS Student Union (NUSSU) Committee for Information Technology (commIT)  Sep 2022 – Present  • Collaborating with team-mates to support outreach strategies and promote NUSSU commIT  • Self-initiated a new email automation method and improved efficiency by at least 70%  • Drafted emails and conducted mass email sending campaigns to look for sponsorship for commIT’s flagship events   ACHIEVEMENTS  Certificate of Distinction in the Analytics Techniques Knowledge Area  • Scored an average of at least 4.5 / 5.0 in three modules offered by NUS: Computational Methods for Business Analytics, Econometrics Modelling for Business Analytics and Feature Engineering for Machine Learning  Top Student in Feature Engineering for Machine Learning  • Being awarded the Outstanding Performance for Feature Engineering for Machine Learning in AY 2021/2022 Semester 2  AWS x Carro Hackathon 2022 (4th place)  • Derived a full pipeline with an accuracy of 87% to solve computer vision real world problems • Optimized a sound classification model with an accuracy of 93% to identify faulty car engines KEY SKILLS  Python, R, Java, PHP, Data Mining, Feature Engineering, Data Analysis, Data Visualization (Tableau, R, Matplotlib), Machine Learning Pipeline Design, NLP (BERT, Glove), SQL(MySQL, Oracle SQL), NoSQL (MongoDB), Time Series Analysis (SARIMA, GARCH)  AVAILABILITY PERIOD  • 5 May 2023 – 29 Dec 2023 (3-month summer internship or 6-month internship) '
test2 = df1.iloc[300,1]

# %% [markdown]
# Text Pre-processing functions

# %%
# load pre-trained model
nlp = spacy.load('en_core_web_sm')
# Tokenize words only with the whitespace rule
# N-grams will no longer be treated as 'N' and '-grams'
nlp.tokenizer = Tokenizer(nlp.vocab, token_match=re.compile(r'\S+').match)

def preprocess(txt):
    txt = txt.lower()
    # these must come first
    txt = re.sub('b\.\S*', '', txt) # remove all bachelor qualifications
    txt = re.sub('m\.\S*', '', txt) # remove all master qualifications
    
    txt = txt.replace("'","").replace("’","") # remove apostrophes
    txt = re.sub("<.*?>"," ",txt) # remove <> tags
    txt = re.sub('http\S+\s*', ' ', txt)  # remove URLs
    txt = re.sub('RT|cc', ' ', txt)  # remove RT and cc
    txt = re.sub('#\S+', '', txt)  # remove hashtags
    txt = re.sub('@\S+', '  ', txt)  # remove mentions
    txt = re.sub('[^a-zA-Z]', ' ', txt) # Remove non-English characters
    txt = re.sub('\s+', ' ', txt)  # remove extra whitespace

    # tokenize word
    txt = nlp(txt)

    # remove stop words and lemmatization
    txt = [token.lemma_ for token in txt if not token.is_stop]

    return ' '.join(txt)

def n_grams(tokens, n):
    return [' '.join(tokens[i:i+n]) for i in range(len(tokens)-n+1)]

def topic_modelling(resume_text, num_words=10, min_prob = 10**-2):
    doc_clean = [resume_text.split()]   
    
    # term dictionary
    dictionary = corpora.Dictionary(doc_clean)

    # Converting list of documents (corpus) into Document Term Matrix using dictionary prepared above.
    doc_term_mat = [dictionary.doc2bow(doc) for doc in doc_clean]

    # latent dirichlet allocation model 
    Lda = gensim.models.ldamodel.LdaModel

    ldamodel = Lda(doc_term_mat, num_topics=1, id2word = dictionary, passes=50)
    
    # Return only the topic words that have the probability of larger than .01
    return [token for token, prob in ldamodel.show_topic(0, topn=num_words) if prob > min_prob]

def generate_list_of_skills(text):
  nlp_text = nlp(text)

  # removing stop words and implementing word tokenization
  tokens = [token.text for token in nlp_text if not token.is_stop]
  # all the resume skills will be saved here
  skillset = []
    
  # check for one-grams (example: python)
  for token in tokens:
      if nlp(token)[0].tag_ != 'VBN':
          skillset.append(token)
    
  # check for noun_chunks (example: machine learning)
  for token in nlp_text.noun_chunks:
      token = token.text.lower().strip()
      skillset.append(token)

  # check for bigrams that SpaCy missed in the noun_chuncks
  for token in n_grams(tokens, 2):
      token = token.lower().strip()
      skillset.append(token)

  # check for trigrams that SpaCy missed in the noun_chuncks
  for token in n_grams(tokens, 3):
      token = token.lower().strip()
      skillset.append(token)

  # check for LDA topic modelling result
  skillset.extend(topic_modelling(text))

  return skillset

# %% [markdown]
# Skills Extraction from Resume Functions

# %%
def extract_skills(resume_text, skills_api, clean=True):
    if clean == True:
        resume_text = preprocess(resume_text)
    
    skillset = set([i for i in set([i.lower() for i in generate_list_of_skills(resume_text)])])
    return skillset.intersection(skills_api)

def date_search(resume):
    ans = []

    # find all the date occurrence based on the regular expression
    pattern = r'(((Jan(uary)?|Feb(ruary)?|Mar(ch)?|Apr(il)?|May|Jun(e)?|Jul(y)?|Aug(ust)?|Sep(tember)?|Nov(ember)?|Dec(ember)?)|(\d{1,2}\s?\/){0,2}|(\d{1,2}\s?\-){0,2})\s?[-/ ]?\s?\d{4}?)|\bPresent\b|\bpresent\b|\bCurrent\b|\bcurrent\b'
    res = list(re.finditer(pattern, resume))

    if len(res) > 1:
        for ele in res:
            # this is to eradicate the results of having only year but without month
            if len(ele.group().strip()) > 5:
                ans.append([ele.start(), ele.end(), ele.group().strip()])

    # Convert "present" and "current" to today's date
    for ele in ans:
        if ele[2].lower() == 'present' or ele[2].lower() == 'current':
            today = pd.to_datetime('today').date()
            ele[2] = today
        else:
            day = pd.to_datetime(ele[2]).date()
            ele[2] = day
    
    # all the date results are given in the form of [datetime_start_index, datetime_end_index, datetime]
    return ans

def experience_tagging(date_list):
    i = 1
    cleaned_section = {}

    while i < len(date_list):

        prev = date_list[i-1]
        cur = date_list[i]
        
        if cur[0] < prev[1] + 10:
            # Taking ceiling of the year of experience
            key = ((cur[2] - prev[2]).days // 365) + 1
            
            # section starts at the (end index of the current date) + 1
            frm = cur[1]+1

            if i < len(date_list) - 1:
                # if there is another date that appears later, then the section will be until the start index of the next date
                until = date_list[i+1][0]
            else:
                # else the section will be until the end of the resume
                until = -1
            

            # Multiple projects with same year of experience, we do 'chaining' here
            if key in cleaned_section:
                cleaned_section[key].append((frm, until))
            else:
                cleaned_section[key] = [(frm, until)]
            i += 2

        else:

            # ignore the current date, possibly it is useless
            i += 1

    return cleaned_section

def skills_experience_level_identification(resume):
    res = {}
    date_list = date_search(resume)
    experience_sec = experience_tagging(date_list)

    for key in experience_sec:
        for start, end in experience_sec[key]:
            skills_list = extract_skills(resume[start:end], skills_api, True)
            for ele in skills_list:
                if ele not in res:
                    res[ele] = key
                else:
                    res[ele] = max(key, res[ele])

    skills_list = extract_skills(resume, skills_api, True)
    for ele in skills_list:
        if ele not in res:
            res[ele] = 1

    return dict(sorted(res.items(), key = lambda x:x[1], reverse = True))

# %% [markdown]
# Test Cases Output

# %%
resume_skills = skills_experience_level_identification(test2)
resume_skills
# Out:
# {'management': 18,
#  'netscaler': 18,
#  'business continuity': 18,
#  'active directory': 18,
#  'capacity planning': 18,
#  'planning': 18,
#  'application deployment': 18,
#  'firewall': 18,
#  'reliability': 18,
#  'r': 18,
#  'reduction': 18,
#  'disaster recovery': 18,
#  'research': 18,
#  'application development': 18,
#  'web development': 3,
#  'system administration': 3,
#  'network support': 3,
#  'group policy': 3,
#  'troubleshooting': 1,
#  'technical support': 1,
#  'project management': 1,
#  'installation': 1,
#  'desktop support': 1,
#  'ghost': 1,
#  'citrix certified administrator': 1,
#  'adware': 1,
#  'spyware': 1,
#  'adobe acrobat': 1,
#  'b': 1,
#  'information technology': 1}

# %% [markdown]
# ## 4. Job Description Data Exploration

# %%
pd.set_option('display.max_rows', 1000)
df2["category"].value_counts()
# Out:
# Registered Nurses                                                                               2513
# Personal Care Aides                                                                              508
# Social and Human Service Assistants                                                              415
# Home Health Aides                                                                                393
# Medical and Health Services Managers                                                             253
# Physical Therapists                                                                              154
# Regulatory Affairs Managers                                                                        1
# Automotive Master Mechanics                                                                        1
# Social Science Research Assistants                                                                 1
# Hospitalists                                                                                       1
# Civil Engineering Technicians                                                                      1
# Construction Carpenters                                                                            1
# Material Moving Workers, All Other                                                                 1
# Cooks, Restaurant                                                                                  1
# Legal Secretaries                                                                                  1
# Skincare Specialists                                                                               1
# Assemblers and Fabricators, All Other                                                              1
# Human Factors Engineers and Ergonomists                                                            1
# Concierges                                                                                         1
# Intelligence Analysts                                                                              1
# Audio and Video Equipment Technicians                                                              1
# Recreation Workers                                                                                 1
# Fitness Trainers and Aerobics Instructors                                                          1
# Epidemiologists                                                                                    1
# Self-Enrichment Education Teachers                                                                 1
# Equal Opportunity Representatives and Officers                                                     1
# Landscape Architects                                                                               1
# Inspectors, Testers, Sorters, Samplers, and Weighers                                               1
# Plasterers and Stucco Masons                                                                       1
# Library Assistants, Clerical                                                                       1
# Interior Designers                                                                                 1
# Speech-Language Pathology Assistants                                                               1
# Insurance Claims Clerks                                                                            1
# Environmental Science and Protection Technicians, Including Health                                 1
# Reservation and Transportation Ticket Agents and Travel Clerks                                     1
# Food Batchmakers                                                                                   1
# Neurologists                                                                                       1
# Actuaries                                                                                          1
# Correctional Officers and Jailers                                                                  1
# Electronics Engineers, Except Computer                                                             1
# Reporters and Correspondents                                                                       1
# Industrial Production Managers                                                                     1
# Chemical Technicians                                                                               1
# Farmers, Ranchers, and Other Agricultural Managers                                                 1
# Criminal Investigators and Special Agents                                                          1
# Administrative Law Judges, Adjudicators, and Hearing Officers                                      1
# Counter Attendants, Cafeteria, Food Concession, and Coffee Shop                                    1
# Health Technologists and Technicians, All Other                                                    1
# Electronics Engineering Technicians                                                                1
# Production Workers, All Other                                                                      1
# Insurance Adjusters, Examiners, and Investigators                                                  1
# Computer Network Architects                                                                        1
# Name: category, dtype: int64

# %% [markdown]
# Skills Extraction from Job Description Function

# %%
def extract_job_skills(job_texts, skills_api, clean=True):
  skillset_summary = {}

  for job_text in job_texts:
    if clean == True:
        job_text = preprocess(job_text)
    
    # get frequency in each document
    skillset = [i.lower() for i in generate_list_of_skills(job_text)]
    skillset_count = {}
    for skill in skillset:
      if skill in skills_api:
        if skill in skillset_count:
          skillset_count[skill] = skillset_count[skill] + 1
        else:
          skillset_count[skill] = 1

    
    for skill in skillset_count:
      '''
      # sum up frequency inside summary dictionary
      if skill in skillset_summary:
        skillset_summary[skill] = skillset_summary[skill] + skillset_count[skill]
      else:
        skillset_summary[skill] = skillset_count[skill]
      '''

      # append frequency inside summary dictionary 
      if skill in skillset_summary:
        skillset_summary[skill].append(skillset_count[skill])
      else:
        skillset_summary[skill] = [skillset_count[skill]]

  # get mean frequency
  for skill in skillset_summary:
    lst = skillset_summary[skill]
    skillset_summary[skill] = sum(lst)/len(lst)
  
  
  return dict(sorted(skillset_summary.items(), key = lambda x:x[1], reverse = True))

# %% [markdown]
# Test Cases

# %%
job = "software developer"
job_texts = list(df2[df2["category"].str.lower().str.contains(job)]["job_requirements"])
print(job_texts,"\n")

job_skills = extract_job_skills(job_texts,skills_api,clean=True)
job_skills
# Out:
# ['* Be familiar with software development methodologies * Understand object-oriented programming * Familiar with design and architectural patterns * Object-oriented analysis, design using UML or similar methodologies. * Experience of software configuration management * Experience of full project life-cycle * Experience of Requirements Management * Familiarity with a Linux environment * Knowledge of cryptographic techniques and their application in products/systemsAn exciting opportunity has arisen for a Software Engineer C# within Airbus Cyber Security in Newport, South Wales. You will report directly to the Software Team Lead for performing allocated Software Work Packages within agreed cost, time and quality constraints. Task & accountabilities : The Software Engineer C# designs, implements, and integrates a software module or component as directed by the Software Team Lead, this will include the production of full design documentation and UML models associated with the software module. Your main tasks will include: * Design and develop software products for the management and distribution of cryptographic information, certificates and essential material, and for managing cryptographic systems and devices protecting critically sensitive national and commercial information. * Software products must achieve the required safety, security, quality and performance levels according to Airbus software engineering processes and the needs of our customers. * Contribute across the full development life-cycle for custom cryptographic products and systems, in collaboration with systems, hardware, FPGA and verification engineers * Allocated Work Packages are completed by the job holder within agreed cost, time and quality constraints Tools, methodologies and coding standards are applied to achieve project aims, following direction from the team lead. * Technical design decisions are made within the context of known practices and acquired technical expertise.', "They are looking for a Senior Data Engineer to join and help lead the teams and projects. My client need someone who is dedicated and will seek to identify improvements and efficiency's, while utilising new technologies and existing tools. Who you'll be working with: It's not what you do; it's how you do it. They embrace fresh thinking - after all, the world is constantly changing and business' adapt with it. You will work as part of a cross-functional agile delivery team, including analysts, architects, big data engineers and testers. They appreciate the knowledge and skills the each one of their employees brings to the business. What you'll be doing: You will be a hands on leader resolving complex problems and implementing high performance solutions that will run on top of the cloud based big data platform. They will be looking for you to help evolve common standards and best practices as they continue on a journey of change. You will use your strong leadership skills when collaborating with other colleagues and external consultants to help be the best that the company can be.", 'You should have proven experience using SQL Server, SSMS, MS Excel, data quality and report development. Project management experience and knowledge of Agile and Lean methodologies would be desirable.This role is one where your responsibilities will be varied and challenging. Your primary focus will be to provide data analysis and project management to various teams in the business, including Finance and Business Development. Along with this you will be responsible for the support and maintenance of the commercial SQL Server platform. You should have a high level of SQL knowledge which you will use daily to support and develop the database environment. Your role will be fast-paced and you will be expected to develop QA measures and assist with their testing as well as researching/testing solutions to provide an improved performance analysis. The team have recently introduced Power BI and a big part of y ...
# {'salesforce': 8.0,
#  'snowflake': 5.0,
#  'reliability': 3.4,
#  'signal processing': 3.0,
#  'information architecture': 3.0,
#  'geology': 3.0,
#  'security clearance': 2.5,
#  'splunk': 2.5,
#  'sql': 2.411764705882353,
#  'r': 2.3333333333333335,
#  'c': 2.3157894736842106,
#  'finance': 2.0,
#  'power bi': 2.0,
#  'middleware': 2.0,
#  'governance': 2.0,
#  'track': 2.0,
#  'logging': 2.0,
#  'runbook': 2.0,
#  'application development': 2.0,
#  'market development': 2.0,
#  'ubuntu': 2.0,
#  'source': 2.0,
#  'magento': 2.0,
#  'operational efficiency': 2.0,
#  'reconciliation': 2.0,
#  'conceptualization': 2.0,
#  'prototype': 2.0,
#  'usability': 2.0,
#  'constructive feedback': 2.0,
#  'usability testing': 2.0,
#  'oauth': 2.0,
#  'openid': 2.0,
#  'aurelia': 2.0,
#  'android': 2.0,
#  'public cloud': 2.0,
#  'docker container': 2.0,
#  'foreign language': 2.0,
#  'rest api development': 2.0,
#  'selenium': 2.0,
#  'opengl': 2.0,
#  'django': 2.0,
#  'databricks': 2.0,
#  'matillion': 2.0,
#  'talend': 2.0,
#  'b': 2.0,
#  'data integration': 2.0,
#  'perl': 2.0,
#  'amazon redshift': 2.0,
#  'java': 1.9090909090909092,
#  'scrum': 1.8571428571428572,
#  'automation': 1.8,
#  'management': 1.7692307692307692,
#  'business intelligence': 1.75,
#  'javascript': 1.7142857142857142,
#  'tooling': 1.6666666666666667,
#  'machine learning': 1.6,
#  'python': 1.56,
#  'angular': 1.5,
#  'solution design': 1.5,
#  'php': 1.5,
#  'deep learning': 1.5,
#  'm': 1.5,
#  'mysql': 1.5,
#  'cloud infrastructure': 1.5,
#  'qlikview': 1.5,
#  'data science': 1.5,
#  'azure data factory': 1.5,
#  'project management': 1.4,
#  'computer science': 1.4,
#  'docker': 1.3636363636363635,
#  'cyber security': 1.3333333333333333,
#  'sas': 1.3333333333333333,
#  'scale': 1.3333333333333333,
#  'problem solving': 1.3333333333333333,
#  'puppet': 1.3333333333333333,
#  'user interface': 1.3333333333333333,
#  'software development': 1.3076923076923077,
#  'continuous integration': 1.2857142857142858,
#  'warehousing': 1.25,
#  'linux': 1.2,
#  'typescript': 1.2,
#  'git': 1.2,
#  'ansible': 1.2,
#  'research': 1.1666666666666667,
#  'terraform': 1.1428571428571428,
#  'programming': 1.0,
#  'collaboration': 1.0,
#  'configuration management': 1.0,
#  'product management': 1.0,
#  'software engineering': 1.0,
#  'technical design': 1.0,
#  'software configuration management': 1.0,
#  'software product management': 1.0,
#  'software engineering process': 1.0,
#  'leadership': 1.0,
#  'dashboard': 1.0,
#  'data quality': 1.0,
#  'business development': 1.0,
#  'performance analysis': 1.0,
#  'commercial focus': 1.0,
#  'openapi': 1.0,
#  'jira': 1.0,
#  'bitbucket': 1.0,
#  'planning': 1.0,
#  'time management': 1.0,
#  'relationship building': 1.0,
#  'development testing': 1.0,
#  'quality assurance': 1.0,
#  'transformation': 1.0,
#  'digital transformation': 1.0,
#  'process lifecycle': 1.0,
#  'chef': 1.0,
#  'enthusiasm': 1.0,
#  'jquery': 1.0,
#  'public transport': 1.0,
#  'azure automation': 1.0,
#  'unix': 1.0,
#  'penetration testing': 1.0,
#  'capitalism': 1.0,
#  'nice': 1.0,
#  'make': 1.0,
#  'specflow': 1.0,
#  'nosql': 1.0,
#  'swift': 1.0,
#  'sql azure': 1.0,
#  'entity framework': 1.0,
#  'application client': 1.0,
#  'instrumentation': 1.0,
#  'creative design': 1.0,
#  'user experience': 1.0,
#  'interface design': 1.0,
#  'user interface design': 1.0,
#  'docker swarm': 1.0,
#  'continuous delivery': 1.0,
#  'java apis': 1.0,
#  'case management': 1.0,
#  'organic growth': 1.0,
#  'life support': 1.0,
#  'public service': 1.0,
#  'career development': 1.0,
#  'troubleshooting': 1.0,
#  'data mining': 1.0,
#  'unit testing': 1.0,
#  'travel insurance': 1.0,
#  'business process': 1.0,
#  'information management': 1.0,
#  'tensorflow': 1.0,
#  'keras': 1.0,
#  'library': 1.0,
#  'kubeflow': 1.0,
#  'natural language processing': 1.0,
#  'scala': 1.0,
#  'dataset': 1.0,
#  'data engineering': 1.0,
#  'data warehousing': 1.0,
#  'cloud migration': 1.0,
#  'cacti': 1.0,
#  'postgresql': 1.0,
#  'prometheus': 1.0,
#  'scripting': 1.0,
#  'bash': 1.0,
#  'innovation': 1.0,
#  'customer service': 1.0,
#  'data migration': 1.0,
#  'stakeholder management': 1.0,
#  'internet security': 1.0,
#  'software architecture': 1.0,
#  'test automation': 1.0,
#  'psychology': 1.0,
#  'inquiry': 1.0,
#  'biology': 1.0,
#  'chemistry': 1.0,
#  'invision': 1.0,
#  'sketch': 1.0,
#  'investigation': 1.0,
#  'resourcefulness': 1.0,
#  'ideation': 1.0,
#  'writing': 1.0,
#  'teamwork': 1.0,
#  'information design': 1.0,
#  'heuristic evaluation': 1.0,
#  'collaborative design': 1.0,
#  'peer review': 1.0,
#  'user research': 1.0,
#  'research design': 1.0,
#  'contextual inquiry': 1.0,
#  'microsoft office': 1.0,
#  'visual design': 1.0,
#  'product design': 1.0,
#  'brand identity': 1.0,
#  'optimal design': 1.0,
#  'field research': 1.0,
#  'adobe creative cloud': 1.0,
#  'algorithms': 1.0,
#  'customer support': 1.0,
#  'talent management': 1.0,
#  'data management': 1.0,
#  'drawing': 1.0,
#  'key management': 1.0,
#  'integration testing': 1.0,
#  'product liability': 1.0,
#  'tableau': 1.0,
#  'performance tuning': 1.0,
#  'database administration': 1.0,
#  'restful api': 1.0,
#  'big data': 1.0,
#  'product quality': 1.0,
#  'dataflow': 1.0,
#  'winrm': 1.0,
#  'visualization': 1.0,
#  'data extraction': 1.0,
#  'file format': 1.0,
#  'groovy': 1.0,
#  'json': 1.0,
#  'hdinsight': 1.0,
#  'mongodb': 1.0,
#  'scalability': 1.0,
#  'resilience': 1.0,
#  'version control': 1.0,
#  'agile methodology': 1.0,
#  'web worker': 1.0,
#  'business analysis': 1.0,
#  'artificial intelligence': 1.0,
#  'microsoft azure': 1.0,
#  'azure cosmos db': 1.0,
#  'debugging': 1.0,
#  'computer vision': 1.0,
#  'volume testing': 1.0,
#  'installation': 1.0,
#  'mathematics': 1.0,
#  'fortran': 1.0,
#  'qt': 1.0,
#  'opencl': 1.0,
#  'testrail': 1.0,
#  'jenkins': 1.0,
#  'cmake': 1.0,
#  'physics': 1.0,
#  'physical science': 1.0,
#  'engineering geology': 1.0,
#  'petroleum engineering': 1.0,
#  'structural geology': 1.0,
#  'graphical user interface': 1.0,
#  'github': 1.0,
#  'experience design': 1.0,
#  'bootstrap': 1.0,
#  'english language': 1.0,
#  'zurb foundation': 1.0,
#  'server administration': 1.0,
#  'core product': 1.0,
#  'statistical analysis': 1.0,
#  'team management': 1.0,
#  'perspective': 1.0,
#  'marketing': 1.0,
#  'alteryx': 1.0,
#  'airflow': 1.0,
#  'data acquisition': 1.0,
#  'real time data': 1.0,
#  'togaf': 1.0,
#  'servicenow': 1.0,
#  'syntax': 1.0,
#  'aws serverless': 1.0,
#  'enterprise architecture': 1.0,
#  'electronic hardware': 1.0,
#  'leadership development': 1.0,
#  'ruby': 1.0,
#  'solution delivery': 1.0,
#  'hadoop cloudera': 1.0,
#  'salesforce development': 1.0,
#  'salesforce certification': 1.0,
#  'code review': 1.0,
#  'low latency': 1.0,
#  'data processing': 1.0,
#  'framework design': 1.0,
#  'heroku': 1.0,
#  'development environment': 1.0,
#  'clojure': 1.0,
#  'functional programming': 1.0}

# %% [markdown]
# ## 5. Identifying Gaps among Candidate's Skills and Job's Required Skills

# %% [markdown]
# We use a function to place the candidate's skills and the skills of the required role into three levels "1, 2, 3". From there, we compare the levels between the candidate and the role and the output gives us a dictionary where the key is the skill and the level required for the candidate to achieve.

# %%
def resume_level_deduction(years):
  if years <= 2:
    return 3
  elif years <= 5:
    return 4
  else:
    return 5

# np.percentile(agg_data['ACCOUNTANT'][agg_data['ACCOUNTANT'] != 0], 95)
def job_level_deduction(count,max_count):
  if count < max_count * 0.05: # remove skill
    return 0
  elif count < max_count * 0.3: # entrant level
    return 3
  elif count < max_count * 0.7:  # specialist level
    return 4
  else:                      # expert level
    return 5

def extract_gap(job_skills, resume_skills):
  gap_skills = {}
  max_count = max(job_skills.values())
  for skill in job_skills:

    count = job_skills[skill]
    job_level = job_level_deduction(count,max_count)
    if job_level == 0:
      continue
    
    elif skill not in resume_skills: 
      gap_skills[skill] = [l for l in range(1,job_level+1)]

    else:
      resume_level = resume_level_deduction(resume_skills[skill])
      if resume_level >= job_level:
        continue
      else:
        gap_skills[skill] = [l for l in range(resume_level+1,job_level+1)]
  
  return dict(sorted(gap_skills.items(), key = lambda x:x[1], reverse = True))

# %%
gap_skills = extract_gap(job_skills, resume_skills)
gap_skills
# Out:
# {'salesforce': [1, 2, 3],
#  'snowflake': [1, 2],
#  'signal processing': [1],
#  'information architecture': [1],
#  'geology': [1],
#  'security clearance': [1],
#  'splunk': [1],
#  'sql': [1]}

# %%
# Yung Jer's function
# Change format for dot2vec

# %% [markdown]
# Course Data Exploration

# %%
pd.read_excel('/content/drive/MyDrive/BT4103/Courses_New.xlsx')
# Out:
#       productId                                     Marketing Name  \
# 0         203.0                                      Private Cloud
# 1         703.0                       Business Process Engineering
# 2         704.0                                         Express BI
# 3         711.0                    Advanced Digital Marketing (SF)
# 4        1305.0              Data Modelling & Transformation (SAP)
# ...         ...                                                ...
# 1175    15506.0  Bachelor Degree Software Engineering Politekni...
# 1176    15601.0  Bachelor of Technology in Software Engineering...
# 1177    15902.0  Bachelor of Technology in Software Engineering...
# 1178    15903.0  Bachelor of Technology in Software Engineering...
# 1179    15904.0               Reskilling- Full Stack Web Developer
#
#                                           courseName  \
# 0                               NICF - Private Cloud
# 1             NICF-Business Process Engineering (SF)
# 2                                         Express BI
# 3                  NICF - Advanced Digital Marketing
# 4           NICF - Data Modelling and Transformation
# ...                                              ...
# 1175            Bachelor Degree Software Engineering
# 1176         Bachelor Degree of Software Engineering
# 1177  Bachelor of Technology in Software Engineering
# 1178  Bachelor of Technology in Software Engineering
# 1179           Reskilling - Full Stack Web Developer
#
#                                              courseDesc  \
# 0     This course is intended for information techno...
# 1     This module examines the strategic and organiz...
# 2     This course provides the learner with knowledg...
# 3     Lithan’s Advanced Digital Marketing enables th...
# 4     This course&nbsp;of study provides Learners wi...
# ...                                                 ...
# 1175  This course is a work-study degree program des...
# 1176  This course is a work-study degree program des...
# 1177  This course is a work-study degree program des...
# 1178  This course is a work-study degree program des...
# 1179  Lithan’s reskilling course in Web Development ...
#
#                                     Outcome Description  \
# 0     Learn how to manage and administer a cloud env...
# 1     Strategic and organizational issues of process...
# 2     Implement and administer SAP Net Weaver Busine...
# 3     Learn digital marketing strategies, customer l...
# 4     Learn how to extract master data and transacti...
# ...                                                 ...
# 1175  Learn front end programming skills such as HTM...
# 1176  Learn front end programming skills such as HTM...
# 1177  Learn front-end development through HTML, CSS,...
# 1178  Learn front-end development through HTML, CSS,...
# 1179  Utilizing the latest application development t...
#
#                                              moduleName competencyUnitCode  \
# 0              Monitoring and Operating a Private Cloud      IT-CLA-503S-1
# 1     NICF-Business Process Engineering (SF) (TGS-20...   ICT-SNA-5012-1.1
# 2                NICF - Data Modelling & Transformation       IT-DE-502S-1
# 3                     NICF - Advanced Digital Marketing      IT-DIG-501S-1
# 4                NICF - Data Modelling & Transformation       IT-DE-502S-1
# ...                                                 ...                ...
# 1175                          Front-End Web Development     App-Degree-FED
# 1176                              Front End Development     App-Degree-FED
# 1177                              Front End Development     App-Degree-FED
# 1178                              Front End Development     App-Degree-FED
# 1179               WSQ Web Development Foundations (SF)   ICT-DIT-3002-1.1
#
#                                      competencyUnitDesc  \
# 0     Design cloud infrastructure architecture (3 Cr...
# 1             Enterprise architecture (2 Credit Values)
# 2     Design extract, transform and load (ETL) proce...
# 3     Develop digital marketing campaign (3 Credit V...
# 4     Design extract, transform and load (ETL) proce...
# ...                                                 ...
# 1175                          Front-End Web Development
# 1176                          Front-End Web Development
# 1177                          Front-End Web Development
# 1178                          Front-End Web Development
# 1179                           Applications Development
#
#                                        jobFamily    competencyLevel
# 0                                Cloud Computing   5 - Expert Level
# 1                    Infrastructure Architecture   5 - Expert Level
# 2                  Software Design & Development   5 - Expert Level
# 3     Digital Advertising / Digital Distribution   5 - Expert Level
# 4                  Software Design & Development   5 - Expert Level
# ...                                          ...                ...
# 1175               Software Design & Development  3 - Entrant Level
# 1176               Software Design & Development  3 - Entrant Level
# 1177               Software Design & Development  3 - Entrant Level
# 1178               Software Design & Development  3 - Entrant Level
# 1179               Software Design & Development  3 - Entrant Level
#
# [1180 rows x 10 columns]

# %%
pd.set_option('display.max_rows', 1000)
df3 = pd.read_excel('/content/drive/MyDrive/BT4103/Courses_New.xlsx')
df3["jobFamily"].value_counts()
# Out:
# Software Design & Development                 514
# Infocomm Sales & Marketing                    195
# Infrastructure Support                        105
# Business Analytics                            105
# Digital Advertising / Digital Distribution    100
# Infrastructure Architecture                    37
# Enterprise Mobility                            17
# Project Management                             16
# Strategy and Architecture                      15
# Service Innovation Design                      14
# Infocomm Security                              13
# Sales and Marketing                            12
# Cloud Computing                                 9
# Data Centre Management                          9
# Product Management                              7
# IT Management                                   5
# Enterprise Network Design Management            5
# IT Outsourcing Management                       1
# Generic Skills                                  1
# Name: jobFamily, dtype: int64

# %%
df3 = pd.read_excel('/content/drive/MyDrive/BT4103/Courses_New.xlsx')
# 'productId', 'competencyUnitCode',
# 'jobFamily', 'Marketing Name', 'courseName', 'moduleName',
# 'courseDesc', 'Outcome Description', 'competencyUnitDesc',
# 'competencyLevel'

# drop irrelevant columns
df3 = df3.drop(columns=['competencyUnitCode'])

# fill null values
df3 = df3.fillna('')

df3["ID"] = df3["productId"]
df3["name"] = df3['Marketing Name']
df3["text"] = " " + df3['jobFamily'] + " " + df3['Marketing Name'] + " " + df3['courseName'] + " " + df3 ['moduleName'] + " " + \
              " " + df3['courseDesc'] + " " + df3['Outcome Description'] + " " + df3['competencyUnitDesc'] + " "
df3["skills"] = df3['text'].apply(lambda x: extract_skills(x,skills_api,clean=True))
df3["text"] = df3["skills"].apply(" ".join)
df3["level"] = df3["competencyLevel"].apply(lambda x: 3 if "5" in x else (2 if "4" in x else 1))

df3 = df3[["ID","level","name","text","skills"]]
df3
#df3.to_csv("/content/drive/MyDrive/BT4103/Courses_Cleaned.csv",index=False)

# %%
def parse_set_string(s):
    if s == '{}':
        return set()
    else:
        words = re.sub('[^a-z\s,]','', s)  
        words_list = words.split(',')
        return set(map(lambda x: str(x).strip(), words_list))

df3 = pd.read_csv("/content/drive/MyDrive/BT4103/Courses_Cleaned.csv",
                  dtype = {'ID': int, 'level': int, 'name': str, 'text': str, 'skills': str})
df3.skills = df3.skills.apply(parse_set_string)
df3
# Out:
#          ID  level                                               name  \
# 0       203      3                                      Private Cloud
# 1       703      3                       Business Process Engineering
# 2       704      3                                         Express BI
# 3       711      3                    Advanced Digital Marketing (SF)
# 4      1305      3              Data Modelling & Transformation (SAP)
# ...     ...    ...                                                ...
# 1175  15506      1  Bachelor Degree Software Engineering <p> Polit...
# 1176  15601      1  Bachelor of Technology in Software Engineering...
# 1177  15902      1  Bachelor of Technology in Software Engineering...
# 1178  15903      1  Bachelor of Technology in Software Engineering...
# 1179  15904      1               Reskilling- Full Stack Web Developer
#
#                                                    text  \
# 0     information technology r cloud infrastructure ...
# 1     enterprise architecture enterprise resource pl...
# 2     software design warehousing extract transform ...
# 3     session dashboard digital advertising digital ...
# 4     sap netweaver software design dimensional anal...
# ...                                                 ...
# 1175  software design prototype software development...
# 1176  software design prototype software development...
# 1177  prototype software design software development...
# 1178  prototype software design software development...
# 1179  project management scale database design softw...
#
#                                                  skills
# 0     {cloud infrastructure, infrastructure architec...
# 1     {management, process design, infrastructure ar...
# 2     {extract transform load, functional specificat...
# 3     {dashboard, session, marketing, digital market...
# 4     {dimensional analysis, business process, extra...
# ...                                                 ...
# 1175  {hibernate, reinforcement, deep learning, soft...
# 1176  {hibernate, reinforcement, deep learning, soft...
# 1177  {reinforcement, deep learning, software design...
# 1178  {reinforcement, deep learning, software design...
# 1179  {management, spring framework, database design...
#
# [1180 rows x 5 columns]

# %%
import time
start_time = time.time()

path = {}

'''
for skill in gap_skills:
# get courses from 3 most similar families
  # df3_group = df3.copy().groupby(['family']).agg(list).reset_index()[["family"]]
  # df3_group["similarity"] = df3_group["family"].apply(lambda x: nlp(skill).similarity(nlp(x)))
  # family = df3_group.nlargest(3,'similarity',keep='all')["family"].values
  # df3_family = df3.copy()
  # df3_family = df3_family[df3_family["family"].isin(family)]

  # get 10 courses with most similar names
  # df3_level["similarity"] = df3_level["name"].apply(lambda x: nlp(skill).similarity(nlp(x)))
  # df3_level = df3_level.nlargest(10,'similarity',keep='all')
'''

for skill in gap_skills:

  # get courses that mention skill
  df3_A = df3.copy()
  df3_A = df3_A[df3_A["skills"].apply(lambda x: skill in x)]

  for level in gap_skills[skill]:

    # get courses of same competency level
    df3_B = df3_A.copy()
    df3_B = df3_B[df3_B["level"].astype(int) == int(level)]

    if df3_B.empty:
      courses = []
      print("No Courses for " + skill + " at level " + str(level) + ".")
    else:
      # get similarity score
      df3_B["similarity"] = df3_B["text"].apply(lambda x: nlp(skill).similarity(nlp(x)))
      top_courses = df3_B.nlargest(3,'similarity',keep='all')
      courses = top_courses["name"].values
      #courses = [(name[:40] + '..') if len(name) > 40 else name for name in courses]
    
    # update path
    for course in courses:
      if level not in path:
        path[level] = {}
      if course not in path[level]:
        path[level][course] = [skill]
      elif skill not in path[level][course]:
        path[level][course].append(skill)

path = dict(sorted(path.items(), key = lambda x:len(x), reverse = True))
for x in path:
  print(x,path[x])

print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# No Courses for salesforce at level 1.
# No Courses for salesforce at level 3.
# No Courses for snowflake at level 1.
# No Courses for snowflake at level 2.
# No Courses for signal processing at level 1.
# No Courses for information architecture at level 1.
# No Courses for geology at level 1.
# No Courses for security clearance at level 1.
# No Courses for splunk at level 1.
# <ipython-input-51-bd41ad70fddd>:37: UserWarning: [W007] The model you're using has no word vectors loaded, so the result of the Doc.similarity method will be based on the tagger, parser and NER, which may not give useful similarity judgements. This may happen if you're using one of the small models, e.g. `en_core_web_sm`, which don't ship with word vectors and only use context-sensitive tensors. You can always add your own word vectors, or use one of the larger models instead if available.
#   df3_B["similarity"] = df3_B["text"].apply(lambda x: nlp(skill).similarity(nlp(x)))
# 2 {'Express CRM (Salesforce)': ['salesforce'], 'Express CRM (Salesforce) <p> for Non-technical Professionals': ['salesforce'], 'Express CRM <p> (with Salesforce CRM) ': ['salesforce']}
# 1 {'Operational Analytics': ['sql'], 'Express Web Developer (PHP)': ['sql'], 'Business Analytics': ['sql']}
# --- 0.25696778297424316 seconds ---

# %%
print(nlp("management").similarity(nlp("cyber security management")))
print(nlp("cyber security management").similarity(nlp("management")))
# Out:
# 0.518793223099013
# 0.518793223099013
# <ipython-input-20-b33acc2765ab>:1: UserWarning: [W007] The model you're using has no word vectors loaded, so the result of the Doc.similarity method will be based on the tagger, parser and NER, which may not give useful similarity judgements. This may happen if you're using one of the small models, e.g. `en_core_web_sm`, which don't ship with word vectors and only use context-sensitive tensors. You can always add your own word vectors, or use one of the larger models instead if available.
#   print(nlp("management").similarity(nlp("cyber security management")))
# <ipython-input-20-b33acc2765ab>:2: UserWarning: [W007] The model you're using has no word vectors loaded, so the result of the Doc.similarity method will be based on the tagger, parser and NER, which may not give useful similarity judgements. This may happen if you're using one of the small models, e.g. `en_core_web_sm`, which don't ship with word vectors and only use context-sensitive tensors. You can always add your own word vectors, or use one of the larger models instead if available.
#   print(nlp("cyber security management").similarity(nlp("management")))
